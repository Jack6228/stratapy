# %% [markdown]
# [![PyPI](https://img.shields.io/badge/PyPI-stratapy-FCB001?logo=pypi)](https://pypi.org/project/stratapy/)
# [![DOI](https://img.shields.io/badge/DOI-10.5281%2Fzenodo.19320013-blue)](https://doi.org/10.5281/zenodo.19320013)
# [![Docs](https://img.shields.io/badge/ReadTheDocs-latest-8ca1af?logo=readthedocs)](https://stratapy.readthedocs.io/en/latest/?badge=latest)
# [![Open In
# Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jack6228/stratapy/blob/master/examples/ManuscriptFigures.ipynb)

# %% [markdown]
# # stratapy: A Tool for Automated Stratigraphic Log Visualisation
#
# This demonstration notebook compliments - and is structured like - the [online documentation for stratapy](https://stratapy.readthedocs.io/en/latest/).
#
# It demonstrates how to use the basic features of stratapy, such as plotting simple logs, as well as more complex features such as plotting multiple logs together, and customising the appearance of plots.
#
# For full details, please refer to the online documentation, which contains more detailed explanations than this notebook, as well as a gallery of example plots.
#
# [![Docs](https://img.shields.io/badge/ReadTheDocs-latest-blue?logo=readthedocs)](https://stratapy.readthedocs.io/en/latest/?badge=latest)
#
# *Struggling to get the notebook to run? Try running it in Google Colab by clicking the button below:*
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jack6228/stratapy/blob/main/main/ManuscriptFigures.ipynb)

# %% [markdown]
# **Contents**
#
# - [Getting Started](#Getting-Started)
#     - [What is stratapy?](#What-is-stratapy?)
#     - [Installation](#Installation)
#     - [Tutorial](#Tutorial)
#         - [File Format](#File-Format)
#         - [Changing the Log Format](#Changing-the-Log-Format)
# - [Customisation Guide](#Customisation-Guide)
#     - [Customisation Options](#Customisation-Options)
#     - [Legend Customisation](#Legend-Customisation)
#     - [Axis Labels](#Axis-Labels)
#     - [Grain Size](#Grain-Size)
#     - [Figure Layout](#Figure-Layout)
#     - [Additional Aspects of Logs](#Additional-Aspects-of-Logs)
#         - [Chronostratigraphy](#Chronostratigraphy)
#         - [Sample Locations](#Sample-Locations)
#         - [Text Labels](#Text-Labels)
#         - [Twin Y Axis](#Twin-Y-Axis)
#         - [Trends](#Trends)
#     - [Advanced Plotting](#Advanced-Plotting)
#         - [Correlated Logs](#Correlated-Logs)
#         - [Multi-Panel Logs](#Multi-Panel-Logs)
#         - [Custom Figure Layouts](#Custom-Figure-Layouts)
#     - [Adjusting Assets](#Adjusting-Assets)
#         - [Lithologies](#Lithologies)
#         - [Minerals](#Minerals)
#         - [Features](#Features)
# - [Reference](#Reference)
#     - [Fonts, Figure Formatting and Image Formats](#Fonts,-Figure-Formatting-and-Image-Formats)
#         - [Background Colour](#Background-Colour)
#         - [Fonts](#Fonts)
#         - [Available Image File Formats](#Available-Image-File-Formats)
#     - [Standalone Chronostratigraphy](#Standalone-Chronostratigraphy)
#     - [Available Example Data](#Available-Example-Data)

# %% [markdown]
# # Getting Started

# %% [markdown]
# ## What is stratapy?

# %% [markdown]
# stratapy is a Python package which enables quick generation and easy visualisation of sedimentary logs (i.e. cores or stratigraphic sections) using stratigraphic data across multiple disciplines i.e., geology, sedimentology, carbonates. It uses simple excel/csv/txt input files to plot stratigraphic columns, ideal for non-programmers. This package enables geoscientists to efficiently document, analyse, and interpret geological layers at both macro- and micro-scales for research, teaching, and any other purposes.
#
# **Why use stratapy?**
#
# stratapy is designed to be quick and user-friendly, allowing geoscientists to create detailed stratigraphic logs without needing extensive programming knowledge and time investment. It supports a wide range of customisation options, enabling users to tailor their logs to specific research needs. The package is built on top of popular libraries like matplotlib, making it powerful yet accessible.
#
# **Key Features**
#
# - **Easy to Use**: Simple input files (Excel/CSV/TXT) for quick log generation.
# - **Key Features**: Supports various types of logs, uses USGS standard patterns, automatically generates legends, and allows for extensive customisation.
# - **Visualisation**: High-quality, publication-ready figures with options for annotations, scales, and colours.
# - **Time-efficient**: Streamlines the process of creating stratigraphic logs, saving time for researchers.
# - **Customisable**: Extensive options for log appearance, including colours, chronostratigraphy, labels, and more. Most aspects of a log can be customised to fit specific needs.
# - **Multi-disciplinary**: Suitable for various fields including geology, sedimentology, tephra, and carbonates.
# - **Advanced Plotting**: Supports complex visualisations like composite logs, subplots, and adding additional data elements like geochemical data plots, bar charts, images, and much more.
# - **Documentation**: Comprehensive guides and examples to help users get started and make the most of the package.

# %% [markdown]
# ## Installation

# %% [markdown]
# To use stratapy, we first need to ensure it is installed. This can be done by running the code cell below.
#
# Note that once this is done, you may need to restart the Notebook kernel to ensure the package is properly imported.
#
# Once installed on a device/system, this command is not needed again. If running this notebook in online environments like Google Colab, you may need to run this cell each time you start a new session.

# %%
# !pip install stratapy

# %% [markdown]
# We can check that the installation was successful by importing the package and checking its version number:

# %%
import stratapy as sp
sp.__version__

# %% [markdown]
# ## Tutorial

# %% [markdown]
# This tutorial will guide you through the process of creating your first stratigraphic log figure using stratapy. By the end of this tutorial, you will have a basic understanding of how to load data, create a log, and customise its appearance.
#
# Stratapy reads data from text-based files (like a .csv file or a spreadsheet .xlsx file). This tutorial will walk through the format of this file (File Format) before showing you how to create and customise a log.

# %% [markdown]
# ### File Format

# %% [markdown]
# To create a stratigraphic log using stratapy, we first need to create an input file. This file is preferably in `.csv` format, but stratapy can also read `.xlsx` or `.txt` files. The file contains columns representing different features of the stratigraphic log.
#
# For full details, refer to the documentation, however for this example, we will use one of the default example files provided with stratapy (`examples.tutorial.csv`), the data of which are shown in the table below.

# %% [markdown]
# | height/age | rock | thickness | bottom_grain | top_grain | connection_type | erosion | lenses | minerals | features | contact |
# |------------|------|-----------|--------------|-----------|-----------------|---------|--------|----------|----------|---------|
# | 2.5 | 607* | | vc | f | | | | | planar laminations | gradational |
# | 2.15 | 601* | | p | vc | | 0.03;0.5 | | glauconite | clasts | |
# | 1.6 | 643* | | c | c | convex | 0.15;0.65 | | | | |
# | 1.2 | 651* | | m | m | | 0.05;0.2 | | | radiolarian | |
# | 0.6 | 602* | | b | cb | concave | 0.03;0.4 | 601* | | rip up clasts;shell hash | |
# | 0.42 | 721 | 0.42 | b | b | | | | | | |

# %% [markdown]
# We can load this - or any other file - by using the `sp.load()` function, as shown below:

# %%
log = sp.load('examples.tutorial.csv')

# %% [markdown]
# This loads the data for the log into a variable called `log`. To visualise this log, we can then simply call the `plot()` method on this variable.
#
# Note that in Jupyter notebooks, the plot will be displayed directly below the code cell by default.

# %%
log.plot()

# %% [markdown]
# Alternatively, we can save this to an image using the `.save()` method with a specified filepath, and optionally use a transparent background:

# %%
log.plot()
log.save('./stratapy_example.png', transparent=True)

# %% [markdown]
# Once the figure is saved, it must be re-plotted to be visualised or saved again.

# %% [markdown]
# ### Changing the Log Format

# %% [markdown]
# To introduce the ways in which stratapy logs can be configured, we will first look at how we can change the format of the log.
#
# The ``display_mode`` parameter allows us to select whether the log is shown with a grainsize x-axis as above (``default``), with a lithology column instead of filled units (``grainsize``), or as a simple log (``log``).
#
# To change the format of the log, we can simply pass the desired parameter to the `plot()` method, as shown below. Note that we do not have to reload the log using `sp.load()`; once a log is loaded, we can plot it repeatedly with different parameters.

# %%
log.plot(display_mode='grainsize')

# Try it: change 'grainsize' with 'log' or 'default' to see other formats

# %% [markdown]
# # Customisation Guide

# %% [markdown]
# ## Customisation Options
#
# stratapy offers a vast range of customisation options to suit needs of users from different fields, and of different level of coding familiarity. This section is split into multiple sections, to help you find what you are looking for quickly, including but not limited to:
#
# - [**Legends**](#Legend-Customisation): Customising the appearance and content of axes labels
#
# - [**Labels**](#Axis-Labels): Customising the appearance and content of labels on the log
#
# - [**Grain Size**](#Grain-Size): Customising the appearance of grain size logs, including brackets, labels, and values
#
# - [**Figure Layout and Sizing**](#Figure-Layout): Adjusting the overall figure dimensions, quality, and more - see
#
# - [**Additional Elements**](#Additional-Aspects-of-Logs): Adding features such as chronostratigraphy, sample locations, and more to your logs
#
# - [**Advanced Plotting**](#Advanced-Plotting): Creating multi-log figures, correlated logs, and bespoke figure layouts
#
# - [**Adjusting Assets**](#Adjusting-Assets): Adjusting the appearance of lithological patterns, minerals, and features, and adding your own custom images

# %% [markdown]
# ## Legend Customisation

# %% [markdown]
# Stratapy provides flexible and powerful options for configuring the legend in your stratigraphic plots. The legend helps explain the meaning of lithologies, minerals, features, and contact types shown in your figure. This guide explains all the ways you can control the legend's appearance and content, both through high-level options and detailed keyword arguments.
#
# The legend is split into sections for various categories, with entries in each section ordered alphabetically, except for the lithologies section, which is ordered chronologically, with oldest units/lenses at the bottom and youngest at the top, based on their first occurrence in the data.
#
# The cells below indicate how parameters can be used to control the legend's location, number of columns, border, and section titles.
#
# See all available parameters and their functions in the documentation.

# %%
# Default legend appearance
log = sp.load('examples.tutorial.csv')
log.plot()

# %%
# Edited legend with 3 columns, a border, and custom section titles.
log = sp.load('examples.tutorial.csv')
log.plot(
    legend_loc='bottom',
    legend_columns=3,
    legend_border=True,
    legend_titles=['Rocks', 'Minerals', 'Structures', 'Fossils', 'Tectonics', 'Contacts'],
)

# %%
# Legend with 2 columns, a border, and custom section titles.
log = sp.load('examples.tutorial.csv')
log.plot(
    legend_loc='left',
    legend_columns=2,
    legend_kwargs={'frameon': False}
)

# %% [markdown]
# stratapy also enables you to create a legend without plotting a log (e.g., for a figure legend or key).
#
# This is done by using the `sp.standalone_legend()` function, which accepts a list of files and will plot a legend for all of the entries in those files, combined.

# %%
# We can pass the same legend parameters to edit the layout, as well as specify the filename and transparency for saving
sp.standalone_legend(['examples.tutorial.csv', 'examples.sedimentary_log.csv'], legend_columns=2, legend_border=True, filename='stratapy_legend_example.png', transparent=True)

# %% [markdown]
# ## Axis Labels

# %% [markdown]
# Axis labels are the text that appears alongside the horizontal (x) and vertical (y) axes of your plot. By default, stratapy does not plot an x-axis label, while the y-axis label is set to 'Age', 'Depth', or 'Height' depending on your data with units of 'Ma' or 'm', respectively. However, you can easily customise these labels to better suit your data and preferences.
#
# The examples below indicate how the axes labels can be adjusted.

# %%
log = sp.load('examples.tutorial.csv')
log.plot(
    x_label='Grain Size',
    y_label='Depth',
    y_axis_unit='m'
)

# %%
log = sp.load('examples.tutorial.csv')
log.plot(
    x_label='',
    y_label='Distance Below Sea Level',
    y_axis_unit='cm',
)

# %%
# If you do not want an axis label to appear, simply set it to an empty string
log = sp.load('examples.tutorial.csv')
log.plot(
    x_label='',
    y_label='',
    y_axis_unit='',
)

# %% [markdown]
# ## Grain Size

# %% [markdown]
# stratapy also allows for customisation of the grain size axis, whether you wish to use presets for different disciplines (e.g., sedimentology, volcanology), or create your own custom grain size axis with specific size classes and positions on the axis.
#
# In either case, this can be achieved by passing parameters to the ``sp.load()`` function when loading the log data, as shown below.
#
# NOTE: the top_grain and bottom_grain columns of the input file can be specified either as numerical values or as strings representing the grain size. Numerical values offer more control over the placement of units, and also more flexibility when creating custom grain size axes.

# %%
# Load a file which uses the 'geological' grain size preset
log = sp.load('./examples.geology_log.csv', grain_preset='geological')
log.plot()

# %% [markdown]
# ## Figure Layout

# %% [markdown]
# Many of the parameters that can be passed to the `plot()` method relate to the overall layout of the figure, such as its dimensions, resolution, and more. These parameters are explained in the documentation, but some of the most commonly used ones are shown below.

# %%
log = sp.load('./examples.tutorial.csv')
log.plot(display_mode='log', figsize=(2,8), ppi=800)
# figsize allows you to set the figure size (width, height) in inches
# dpi adjusts the quality of the figure - higher values give better quality but will take longer to create. It is recommended to use the default value of 100 until you are ready to save the figure.
# ppi adjusts the zoom of the lithological patterns. Higher values give a more zoomed in pattern. Default is 400.

# %%
# These arguments allow customisation of the x and y axis labels
log.plot(x_label='Title', y_label='Distance', y_axis_unit='km')

# %%
# Finally, the legend_* arguments allow customisation of the legend
log.plot(display_mode='log', legend_columns=2, legend_loc='bottom', legend_border=False)

# %% [markdown]
# The grainsize log from earlier can be used to illustrate some other features:

# %%
# feature_mode can be set to 'merge', 'semi-merge', 'default', or 'off' to change how features, lenses, and minerals are displayed
log.plot(display_mode='grainsize', feature_mode='merge')

# %% [markdown]
# ## Additional Aspects of Logs

# %% [markdown]
# stratapy offers easy ways to add additional aspects to logs, such as chronostratigraphy, unit labels, triangles, and more. These are all added following the ``.plot()`` method, each with their own method. Below are examples of the available methods

# %% [markdown]
# ### Chronostratigraphy

# %% [markdown]
# If your log is based on age data, you can add a chronostratigraphic column using the `.add_chronostratigraphy()` method. stratapy will automatically map the ages in your log to the appropriate chronostratigraphic units.
#
#
# The function accepts some optional parameters:
# - ``ranks_to_display = [0, 1, 2, 3, 4, 5]``: a list of chronostratigraphic ranks to display. By default, all ranks are displayed (5 = stage, 4 = series, etc.)
# - ``width_ratio = 0.2``: the width of the chronostratigraphic column as a ratio of the total figure width (default is 0.2)
# - ``spacing = 0.02``: the spacing between the chronostratigraphic column and the main log, as a ratio of the total figure width (default is 0.02)

# %%
# Chronostratigraphy Basic
log = sp.load('./examples.age_based_log_Ka.csv')
log.plot(y_axis_unit='ka')
log.add_chronostratigraphy(ranks_to_display=[3, 4, 5], width_ratio=0.3, spacing=0.05)

# %% [markdown]
# To create standalone chronostratigraphy columns, see []

# %% [markdown]
# ### Sample Locations

# %% [markdown]
# Often, we want to highlight points along a log where sample, photographs, or other data were collected. This can be done using the `.add_samples()` method, which accepts a list of y-axis values where markers should be placed.

# %%
log = sp.load('examples.sedimentary_log.csv')
log.plot(figsize=(6, 10))
# log.add_twin_axis(4.72, label='Above Modern Sea Level (m)', spacing=80)
log.add_samples([1.35, 2.2, 2.9, 3.19], label='Photographs', scatter_kwargs={'color': 'red', 's': 50, 'marker': 'o'})
log.add_samples([2.7, 3.11, 3.42], label='Samples', scatter_kwargs={'color': 'royalblue', 's': 50, 'marker': 's'})
log.add_samples([1.65], scatter_kwargs={'color': 'k', 's': 50, 'marker': '*'})

# %% [markdown]
# The x-position of the points can also be customised using the ``x`` parameter, and any `matplotlib` marker style arguments can be passed to ``scatter_kwargs`` to change the appearance of the markers.

# %% [markdown]
# ### Text Labels

# %%
# Load a log
log = sp.load('examples.age_based_log_Ka.csv')
# Plot the log
log.plot(figsize=(3, 10), display_mode='log', legend_loc='bottom', legend_columns=4)
# Add labels, in this case for the number of OSL samples taken in each unit
log.add_labels(["N = 5", "N = 3", "N = 8", "N = 2"])

# %% [markdown]
# ### Twin Y Axis

# %% [markdown]
# If a second y-axis is desired, perhaps to show a different reference scale or offset to a different scale/datum, this can be added using the `.add_twin_axis()` method. This will create a second y-axis on the left side of the log, with a specified `offset`:

# %%
log = sp.load('./examples.sedimentary_log.csv')
log.plot()
log.add_twin_axis(0.27, label='Above Sea Level (m)')

# %% [markdown]
# ### Trends

# %% [markdown]
# Triangles can be added to the right side of a log using the `.add_triangles()` method. The function requires a list of two y-axis values, [y1, y2], where the triangle will be drawn between in direction y1 to y2.

# %%
log = sp.load('./examples.sedimentary_log.csv')
log.plot(xmax=7.5)
log.add_trends([3, 2.3], x=7.3)

# The `xmax` and `x` arguments allow adjustment of the spacing between the features column and log and the location of the trend line, respectively.

# %% [markdown]
# Additional parameters enable customisation of the triangle type and style:
# - ``triangle_type``: the type of triangle to add; can be 'isosceles' (default) or 'right'
# - ``fill_color``, ``edge_color``, ``linewidth``: styling options for the triangle
#
# And the function can be called repeatedly to add multiple triangles to the log.

# %% [markdown]
# ## Advanced Plotting

# %% [markdown]
# This functionality allows for more complex visualisations and tailored presentations of stratigraphic data, while still being accessible to users with varying levels of programming experience.
#
# Two built-in functions enable the contents of all logs to be placed into a single figure with a shared legend and other useful display options (e.g. vertical alignment and shared axes), which is particularly useful for complex figures with multiple logs. The sections below provide examples of how to use these functions effectively, and how matplotlib can be used to create custom figure layouts with additional panels for complementary data.

# %% [markdown]
# ### Correlated Logs

# %% [markdown]
# The ``correlated_logs()`` function in stratapy is designed for creating side-by-side stratigraphic log plots, making it easy to visually correlate multiple logs, including a shared legend. It also has some optional features to customise the style and alignment of the logs, as highlighted in the documentation.

# %%
files = ['examples.multi_log_1.csv', 'examples.multi_log_2.csv', 'examples.multi_log_3.csv', 'examples.multi_log_4.csv', 'examples.multi_log_5.csv', 'examples.multi_log_6.csv']

panel = sp.correlated_logs(files, figsize=(20, 14), legend_columns=4)

# %% [markdown]
# ### Multi-Panel Logs

# %% [markdown]
# The ``multi_fig()`` function allows you to plot multiple stratigraphic logs in a single figure, each on its own axis, with a shared legend. This is ideal for comparing several logs side-by-side or in a grid, while maintaining individual axes and full customisation for each log.
#
# You can provide your own matplotlib figure and axes, or let ``multi_fig()`` create them automatically, control whether the logs share y-axes or have independent y-axes, and use all the same legend customisation options as for single logs.

# %%
files = ['examples.multi_log_1.csv', 'examples.multi_log_2.csv', 'examples.multi_log_3.csv', 'examples.multi_log_4.csv', 'examples.multi_log_5.csv', 'examples.multi_log_6.csv']

panel = sp.correlated_logs(files, figsize=(20, 14), legend_columns=4)

# %% [markdown]
# ### Custom Figure Layouts

# %% [markdown]
# In addition to the composite and multi-panel figures described earlier, some familiarity with *Python* and `matplotlib` enables offers great flexibility. For those unfamiliar, we have many examples in the documentation which you can view, copy, or modify to suit your needs.
#
# For example, we can create a custom subplot arrangement, and tell stratapy where to plot the log within this figure.
#
# Note that both the figure and axes variables need to be passed to the ``.plot()`` method; legend for the log is drawn with respect to the figure.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6,8), gridspec_kw={'width_ratios': [1, 3]}, sharey=True)
log = sp.load('examples.geology_log.csv')
log.plot(fig=fig, ax=ax[0], display_mode='log', legend_columns=2, feature_size=2)

# Plot some random data on the second axis
ax[1].scatter(
    [0.2, 0.3, 0.2, 0.35, 0.38, 0.4, 0.42, 0.3, 0.25, 0.3, 0.28, 0.26, 0.3, 0.2, 0.3, 0.25],
    [5, 8, 9, 12, 15, 18, 22, 25, 30, 31, 33, 34, 35, 41, 42, 45],
    color='red',
    s=50,
    marker='o',
)

# %% [markdown]
# See the ManuscriptFigures.ipynb notebook in the Github repository for a more complex example of custom figure arrangements.

# %% [markdown]
# ## Adjusting Assets

# %% [markdown]
# stratapy allows for extensive customisation of the appearance of lithologies, minerals, and features in the log.
#
# - **Lithologies**: new lithologies can be added by selecting i) an existing pattern, ii) a colour fill, iii) a name. Custom images (e.g., `.png` files) can also be used as patterns for lithologies.
#
# - **Minerals**: the colours, shapes, and sizes of mineral symbols can be customised.
#
# - **Features**: features can be moved between sections in the legend, names can be changed, and custom images can be used.
#
# The subsections below demonstrate how to achieve these customisations.

# %% [markdown]
# ### Lithologies

# %% [markdown]
# Lithological patterns are customised using a dictionary which is passed to the `sp.update_lithologies()` function. An entry in this dictionary is formatted as follows:
#
# - **key**: name used in your input file (e.g. in ``rock`` column)
# - **value**: ``(pattern, colour, legend_label)``
#    - ``pattern`` = existing lithology name (e.g. ``'sandstone'``), image filename (e.g. ``'my_pattern.png'``), or ``''`` (blank) for solid colour fills
#    - ``colour`` = hex, named colour, RGB tuple, or RGBA tuple
#    - ``legend_label`` = text shown in legend
#
# This can then be passed to the function as:
#
# ```python
# sp.update_lithologies( {
#     'clay': ('', 'red', 'Clay')
# } )
# ```
#
# This example will create a new lithology called ``clay`` which you can input into the ``rock`` column of your input file. When used, it will now create a solid red colour with the label "Clay" in the legend.
#
# Alternatively, we can modify existing lithologies, by creating a new entry with a different name, but which uses that pattern as a base, e.g.:
#
# ```python
# sp.update_lithologies( {
#     "my_limestone": ('limestone', '#FFD700', 'My New Limestone')
# } )
# ```
#
# This will create ``my_limestone`` to be used in the input files, which will use the same lithological pattern as the ``limestone`` lithology, but will be coloured gold (#FFD700) and labelled "My New Limestone" in the legend.

# %% [markdown]
# This method should be employed **before** loading any log files - ideally immediately after importing stratapy.

# %%
# These custom lithologies are used for the UKGeos Observatory project
sp.update_lithologies( {
    'MadeGround': ('667', '', 'Made ground'),
    'CoalPillar': ('216', '', 'Coal pillar and void'),
    'PackedWaste': ('430', '', 'Packed waste'),
    'UKG_sand': ('607', '#FEF5B4', 'Sand'),
    'UKG_sandgravel': ('614', '#FEF5B4', 'Sand and gravel'),
    'UKG_sandclay': ('616', '#FEF5B4', 'Sand and clay'),
    'UKG_claysilt': ('618', "#EAF384", 'Clay, silt, sand and gravel'),
    'UKG_mudstone': ('619', '#989898', 'Mudstone'),
    'UKG_clay': ('620', '#EFEFEF', 'Clay'),
    'UKG_claygravel': ('622', '#EFEFEF', 'Clay and gravel'),
    'UKG_interbed': ('669', "#ADA97A", 'Interbedded sandstone, siltstone, claystone'),
    'no': ('', 'No Observation'),
})

# Load one of the UKGeos files and plot
log = sp.load('./examples.UKGeos_GGA04.csv')
log.plot(display_mode='log')

# %% [markdown]
# ### Minerals

# %% [markdown]
# These can be customised in the same way as lithologies, using the `sp.update_minerals()` function.
#
# For minerals, an entry in the dictionary is formatted as follows:
# - `key`: the name of the mineral to be used in the input file
# - `value`: a tuple containing three elements:
#     - fill colour (e.g., '#FFFF00', 'yellow', (1,1,0))
#     - edge colour
#     - marker shape
#
# Note that for minerals, the display name is the title case of the key.

# %%
sp.update_minerals( {
    # Magenta diamond with black edge - overrides default garnet style
    'garnet': ('#FF00FF', 'k', 'd'),
    # Orange circle with brown edge - new mineral
    'honeystone': ('orange', 'brown', 'o'),
} )

# %% [markdown]
# A full list of available marker shapes can be found in the [Matplotlib documentation](https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers).

# %% [markdown]
# ### Features

# %% [markdown]
# For features, we use ``sp.update_features()`` with the dictionary formatted as:
#
# - `key`: the name of the feature to be used in the input file
# - `value`: a tuple containing three elements:
#     - the type of feature: 'fossil', 'structure', or 'tectonic' (which determines the section of the legend in which the feature appears)
#     - a filepath to a custom image (e.g., 'my_feature.png'), or an existing feature's key (e.g., 'normal grading'), to use that feature's image.
#     - the name to be displayed in the legend

# %%
sp.update_features( {
    # Renames the default 'normal grading' feature to 'Grading' in the legend
    'normal grading': ('', '', 'Grading'),          
    # Moves the default 'Mollusc' feature to the sedimentary structures group
    'mollusc': ('structure', '', 'Mollusc'),               
    # Moves the default 'Bioturbation (med.)' feature to the fossils group, and re-names to 'Bioturbation'
    'bioturbation medium': ('f', '', 'Bioturbation'),   
    # Creates a new 'Scaphopod' feature using the default trace fossil image
    'scaphopod': ('', 'trace fossil', 'Scaphopod'),     
    # Adds a new fossil feature with a custom image and name
    'my_fossil': ('fossil', 'my_fossil.png', 'My Fossil'),
} )

# Here, we get a warning since 'my_fossil' does not exist, but you can use your own file path instead.

# %% [markdown]
# # Reference

# %% [markdown]
# ## Fonts, Figure Formatting and Image Formats
#
# To adjust the font family, size, or the colour style of the figure, the following sections are useful.

# %% [markdown]
# ### Background Colour

# %% [markdown]
# In matplotlib, the figure or axis facecolor can be adjusted using `rcParams`. This must be done before plotting. stratapy will use these colours to ensure consistency across the figure, changing black and white lithologies to match the background where appropriate.
#
# Note that to save a log with a transparent background, these two parameters can be set to `'none'`.

# %%
import matplotlib.pyplot as plt
plt.rcParams.update( {
    'axes.facecolor': 'skyblue',
    'figure.facecolor': 'lightgrey',
} )

log = sp.load('examples.tutorial.csv')
log.plot(display_mode='grainsize')

# %%
# These parameters can be reset using:
plt.rcdefaults()

# %% [markdown]
# ### Fonts

# %% [markdown]
# stratapy has a range of default font sizes for various aspects of the figure:
# - ``x_label_label``: 14
# - ``title``: 14,
# - ``x_axis_label``: 14,
# - ``y_axis_label``: 14,
# - ``x_tick_labels``: 12.8,
# - ``y_tick_labels``: 12.8,
# - ``grain_brackets``: 12.8*.8,
# - ``legend_entry``: 10,
# - ``legend_subtitle``: 11,
# - ``chronostratigraphy_periods``: 11,
# - ``chronostratigraphy_labels``: 12.8
#
# Each can be set using the code below, but this must be done **before** plotting the figure, so that the settings are applied.

# %%
sp.formatting.fontsizes.update( {
    'x_label_label': 18
} )

# Or alternatively

sp.formatting.fontsizes['x_axis_label'] = 18

# %% [markdown]
# The font family can be adjusted using matplotlib's rcParams

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'

# %%
# Reset the font for the rest of the notebook
plt.rcdefaults()

# %% [markdown]
# ### Available Image File Formats

# %% [markdown]
# Run the cell below to see which image file formats are available on your device when saving logs as images.
#
# The ``.save()`` method accepts any of these formats. You may need to install additional libraries to enable some formats.

# %%
import matplotlib.pyplot as plt
plt.gcf().canvas.get_supported_filetypes()

# %% [markdown]
# ## Standalone Chronostratigraphy

# %%
# Create a vertical timescale from 0 to 500 Ma
sp.chronostratigraphy(0, 500)

# %%
# Create a horizontal timescale from 237 to 242 Ma, with a custom figure size and only displaying the stage, series and system ranks
sp.chronostratigraphy(237, 242, orientation='horizontal', figsize=(10, 3), ranks_to_display=[3,4,5])

# %% [markdown]
# ## Available Example Data

# %% [markdown]
# stratapy has a variety of built-in csv files, as have been used throughout this tutorial. The cell below lists all of these files.
#
# Some require custom lithologies or features, details of which can be found by searching the documentation.

# %%
sp.list_examples()
